# %% [markdown]
# ### Q1. Calculate the 95% confidence interval for a sample of data with a mean of 50 and a standard deviation
# of 5 using Python. Interpret the results.

# %%
import scipy.stats as stats

# Sample data
sample_mean = 50
sample_std = 5
sample_size = 100  # Assuming a sample size of 100 for this example

# Calculate the margin of error
confidence_level = 0.95
alpha = 1 - confidence_level
critical_value = stats.norm.ppf(1 - alpha / 2)
margin_of_error = critical_value * (sample_std / (sample_size ** 0.5))

# Calculate the confidence interval
confidence_interval = (sample_mean - margin_of_error, sample_mean + margin_of_error)

print("95% Confidence Interval:", confidence_interval)
# Out:
# 95% Confidence Interval: (49.02001800772997, 50.97998199227003)

# %% [markdown]
# ### Q2. Conduct a chi-square goodness of fit test to determine if the distribution of colors of M&Ms in a bag
# ### matches the expected distribution of 20% blue, 20% orange, 20% green, 10% yellow, 10% red, and 20%
# ### brown. Use Python to perform the test with a significance level of 0.05.

# %%
import numpy as np
from scipy.stats import chisquare

# Observed frequencies (counts) of each color
observed_frequencies = np.array([18, 23, 22, 11, 9, 17])  # Replace with your actual data

# Expected frequencies based on the expected distribution
expected_frequencies = np.array([0.20, 0.20, 0.20, 0.10, 0.10, 0.20]) * observed_frequencies.sum()

# Perform the chi-square goodness of fit test
chi2_stat, p_value = chisquare(observed_frequencies, expected_frequencies)

# Significance level
alpha = 0.05

print("Chi-Square Statistic:", chi2_stat)
print("P-value:", p_value)

if p_value < alpha:
    print("Reject the null hypothesis: The distribution does not match the expected distribution.")
else:
    print("Fail to reject the null hypothesis: The distribution matches the expected distribution.")
# Out:
# Chi-Square Statistic: 1.5
# P-value: 0.9130698145443954
# Fail to reject the null hypothesis: The distribution matches the expected distribution.

# %% [markdown]
# ### Q3. Use Python to calculate the chi-square statistic and p-value for a contingency table with the following
# data:

# %%
import numpy as np
from scipy.stats import chi2_contingency

# Contingency table data
observed_data = np.array([[20, 15],
                          [10, 25],
                          [15, 20]])

# Perform the chi-square test for independence
chi2_stat, p_value, dof, expected = chi2_contingency(observed_data)

print("Chi-Square Statistic:", chi2_stat)
print("P-value:", p_value)
# Out:
# Chi-Square Statistic: 5.833333333333334
# P-value: 0.05411376622282158

# %% [markdown]
# ### Q4. A study of the prevalence of smoking in a population of 500 individuals found that 60 individuals
# ### smoked. Use Python to calculate the 95% confidence interval for the true proportion of individuals in the
# population who smoke.

# %%
import statsmodels.api as sm
import statsmodels.stats.proportion as proportion

# Sample data
sample_size = 500
sample_proportion = 60 / sample_size

# Calculate the confidence interval
conf_interval = proportion.proportion_confint(sample_proportion * sample_size, sample_size, alpha=0.05, method='normal')

print("95% Confidence Interval:", conf_interval)
# Out:
# 95% Confidence Interval: (0.09151638887130706, 0.14848361112869293)

# %% [markdown]
# ### Q5. Calculate the 90% confidence interval for a sample of data with a mean of 75 and a standard deviation
# of 12 using Python. Interpret the results.

# %%
import numpy as np
import scipy.stats as stats

# Sample data
sample_mean = 75
sample_std = 12
sample_size = 100  # Assuming a sample size of 100 for this example

# Calculate the margin of error
confidence_level = 0.90
alpha = 1 - confidence_level
critical_value = stats.norm.ppf(1 - alpha / 2)
margin_of_error = critical_value * (sample_std / (sample_size ** 0.5))

# Calculate the confidence interval
confidence_interval = (sample_mean - margin_of_error, sample_mean + margin_of_error)

print("90% Confidence Interval:", confidence_interval)
# Out:
# 90% Confidence Interval: (73.02617564765823, 76.97382435234177)

# %% [markdown]
# ### Q6. Use Python to plot the chi-square distribution with 10 degrees of freedom. Label the axes and shade the
# area corresponding to a chi-square statistic of 15.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# Degrees of freedom
df = 10

# Create an array of values for the x-axis (chi-square values)
x = np.linspace(0, 30, 500)

# Calculate the chi-square probability density function (PDF)
pdf = stats.chi2.pdf(x, df)

# Create the plot
plt.figure(figsize=(8, 6))
plt.plot(x, pdf, label=f'Degrees of Freedom = {df}')
plt.fill_between(x, pdf, where=(x >= 0) & (x <= 15), color='lightblue', alpha=0.5, label='Area for chi-square = 15')
plt.xlabel('Chi-Square Value')
plt.ylabel('Probability Density')
plt.title('Chi-Square Distribution')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Q7. A random sample of 1000 people was asked if they preferred Coke or Pepsi. Of the sample, 520
# ### preferred Coke. Calculate a 99% confidence interval for the true proportion of people in the population who
# prefer Coke.

# %%
import statsmodels.api as sm
import statsmodels.stats.proportion as proportion

# Sample data
sample_size = 1000
sample_proportion = 520 / sample_size

# Calculate the confidence interval
conf_interval = proportion.proportion_confint(sample_proportion * sample_size, sample_size, alpha=0.01, method='normal')

print("99% Confidence Interval:", conf_interval)
# Out:
# 99% Confidence Interval: (0.4793051576779699, 0.5606948423220302)

# %% [markdown]
# ### Q8. A researcher hypothesizes that a coin is biased towards tails. They flip the coin 100 times and observe
# ### 45 tails. Conduct a chi-square goodness of fit test to determine if the observed frequencies match the
# ### expected frequencies of a fair coin. Use a significance level of 0.05.

# %%
import numpy as np
from scipy.stats import chisquare

# Observed frequencies (tails and heads)
observed_frequencies = np.array([45, 100 - 45])  # [tails, heads]

# Expected frequencies for a fair coin
expected_frequencies = np.array([0.5, 0.5]) * 100

# Perform the chi-square goodness of fit test
chi2_stat, p_value = chisquare(observed_frequencies, expected_frequencies)

# Significance level
alpha = 0.05

print("Chi-Square Statistic:", chi2_stat)
print("P-value:", p_value)

if p_value < alpha:
    print("Reject the null hypothesis: The coin is biased.")
else:
    print("Fail to reject the null hypothesis: The coin is fair.")
# Out:
# Chi-Square Statistic: 1.0
# P-value: 0.31731050786291115
# Fail to reject the null hypothesis: The coin is fair.

# %% [markdown]
# ### Q9. A study was conducted to determine if there is an association between smoking status (smoker or
# ### non-smoker) and lung cancer diagnosis (yes or no). The results are shown in the contingency table below.
# ### Conduct a chi-square test for independence to determine if there is a significant association between
# smoking status and lung cancer diagnosis.

# %%
import numpy as np
from scipy.stats import chi2_contingency

# Contingency table data
observed_data = np.array([[60, 140],   # Smoker: Yes, No
                          [30, 170]])  # Non-smoker: Yes, No

# Perform the chi-square test for independence
chi2_stat, p_value, dof, expected = chi2_contingency(observed_data)

# Significance level
alpha = 0.05

print("Chi-Square Statistic:", chi2_stat)
print("P-value:", p_value)

if p_value < alpha:
    print("Reject the null hypothesis: There is a significant association between smoking status and lung cancer diagnosis.")
else:
    print("Fail to reject the null hypothesis: There is no significant association between smoking status and lung cancer diagnosis.")
# Out:
# Chi-Square Statistic: 12.057347670250895
# P-value: 0.0005158863863703744
# Reject the null hypothesis: There is a significant association between smoking status and lung cancer diagnosis.
